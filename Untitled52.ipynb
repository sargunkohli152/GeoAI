# %%
# !pip install -U leafmap geopandas
# Out:
# Collecting leafmap
#   Downloading leafmap-0.18.5-py2.py3-none-any.whl (212 kB)
#      -------------------------------------- 212.4/212.4 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: geopandas in a:\new folder\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib in a:\new folder\lib\site-packages (from leafmap) (3.5.2)
# Requirement already satisfied: bqplot in a:\new folder\lib\site-packages (from leafmap) (0.12.36)
# Collecting pystac-client
#   Downloading pystac_client-0.6.1-py3-none-any.whl (30 kB)
# Requirement already satisfied: xyzservices in a:\new folder\lib\site-packages (from leafmap) (2023.2.0)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in a:\new folder\lib\site-packages (from leafmap) (0.6.0)
# Collecting folium<=0.13.0,>=0.11.0
#   Downloading folium-0.13.0-py2.py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: gdown in a:\new folder\lib\site-packages (from leafmap) (4.6.4)
# Requirement already satisfied: ipyevents in a:\new folder\lib\site-packages (from leafmap) (2.0.1)
# Requirement already satisfied: python-box in a:\new folder\lib\site-packages (from leafmap) (7.0.1)
# Requirement already satisfied: scooby in a:\new folder\lib\site-packages (from leafmap) (0.7.1)
# Requirement already satisfied: pandas in a:\new folder\lib\site-packages (from leafmap) (1.4.4)
# Requirement already satisfied: geojson in a:\new folder\lib\site-packages (from leafmap) (3.0.1)
# Requirement already satisfied: numpy in a:\new folder\lib\site-packages (from leafmap) (1.21.5)
# Requirement already satisfied: colour in a:\new folder\lib\site-packages (from leafmap) (0.1.5)
# Requirement already satisfied: ipywidgets<8.0.0 in a:\new folder\lib\site-packages (from leafmap) (7.6.5)
# Requirement already satisfied: pyshp>=2.1.3 in a:\new folder\lib\site-packages (from leafmap) (2.3.1)
# Requirement already satisfied: ipyleaflet>=0.17.0 in a:\new folder\lib\site-packages (from leafmap) (0.17.2)
# Requirement already satisfied: whiteboxgui>=0.6.0 in a:\new folder\lib\site-packages (from leafmap) (2.2.0)
# Requirement already satisfied: fiona>=1.8 in a:\new folder\lib\site-packages (from geopandas) (1.9.1)
# Requirement already satisfied: pyproj>=2.6.1.post1 in a:\new folder\lib\site-packages (from geopandas) (3.4.1)
# Requirement already satisfied: shapely>=1.7 in a:\new folder\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: packaging in a:\new folder\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: setuptools in a:\new folder\lib\site-packages (from fiona>=1.8->geopandas) (63.4.1)
# Requirement already satisfied: click-plugins>=1.0 in a:\new folder\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in a:\new folder\lib\site-packages (from fiona>=1.8->geopandas) (2022.9.14)
# Requirement already satisfied: cligj>=0.5 in a:\new folder\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in a:\new folder\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=19.2.0 in a:\new folder\lib\site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: click~=8.0 in a:\new folder\lib\site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: branca>=0.3.0 in a:\new folder\lib\site-packages (from folium<=0.13.0,>=0.11.0->leafmap) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in a:\new folder\lib\site-packages (from folium<=0.13.0,>=0.11.0->leafmap) (2.11.3)
# Requirement already satisfied: requests in a:\new folder\lib\site-packages (from folium<=0.13.0,>=0.11.0->leafmap) (2.28.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in a:\new folder\lib\site-packages (from ipyleaflet>=0.17.0->leafmap) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in a:\new folder\lib\site-packages (from ipywidgets<8.0.0->leafmap) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in a:\new folder\lib\site-packages (from ipywidgets<8.0.0->leafmap) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in a:\new folder\lib\site-packages (from ipywidgets<8.0.0->leafmap) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in a:\new folder\lib\site-packages (from ipywidgets<8.0.0->leafmap) (6.15.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in a:\new folder\lib\site-packages (from ipywidgets<8.0.0->leafmap) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in a:\new folder\lib\site-packages (from ipywidgets<8.0.0->leafmap) (7.31.1)
# Requirement already satisfied: traitlets>=4.3.1 in a:\new folder\lib\site-packages (from ipywidgets<8.0.0->leafmap) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in a:\new folder\lib\site-packages (from pandas->leafmap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in a:\new folder\lib\site-packages (from pandas->leafmap) (2022.1)
# Requirement already satisfied: ipytree in a:\new folder\lib\site-packages (from whiteboxgui>=0.6.0->leafmap) (0.2.2)
# Requirement already satisfied: whitebox in a:\new folder\lib\site-packages (from whiteboxgui>=0.6.0->leafmap) (2.2.0)
# Requirement already satisfied: six in a:\new folder\lib\site-packages (from gdown->leafmap) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in a:\new folder\lib\site-packages (from gdown->leafmap) (4.11.1)
# Requirement already satisfied: tqdm in a:\new folder\lib\site-packages (from gdown->leafmap) (4.64.1)
# Requirement already satisfied: filelock in a:\new folder\lib\site-packages (from gdown->leafmap) (3.6.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in a:\new folder\lib\site-packages (from matplotlib->leafmap) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in a:\new folder\lib\site-packages (from matplotlib->leafmap) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in a:\new folder\lib\site-packages (from matplotlib->leafmap) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in a:\new folder\lib\site-packages (from matplotlib->leafmap) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in a:\new folder\lib\site-packages (from matplotlib->leafmap) (4.25.0)
# Collecting pystac>=1.7.0
#   Downloading pystac-1.7.0-py3-none-any.whl (153 kB)
#      -------------------------------------- 153.9/153.9 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: colorama in a:\new folder\lib\site-packages (from click~=8.0->fiona>=1.8->geopandas) (0.4.5)
# Requirement already satisfied: nest-asyncio in a:\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in a:\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (1.5.1)
# Requirement already satisfied: psutil in a:\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in a:\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in a:\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in a:\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in a:\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (6.1)
# Requirement already satisfied: jedi>=0.16 in a:\new folder\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in a:\new folder\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (3.0.20)
# Requirement already satisfied: decorator in a:\new folder\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (5.1.1)
# Requirement already satisfied: pygments in a:\new folder\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (2.11.2)
# Requirement already satisfied: pickleshare in a:\new folder\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.7.5)
# Requirement already satisfied: backcall in a:\new folder\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in a:\new folder\lib\site-packages (from jinja2>=2.9->folium<=0.13.0,>=0.11.0->leafmap) (2.0.1)
# Requirement already satisfied: jupyter_core in a:\new folder\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0.0->leafmap) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in a:\new folder\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0.0->leafmap) (4.16.0)
# Requirement already satisfied: fastjsonschema in a:\new folder\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0.0->leafmap) (2.16.2)
# Requirement already satisfied: idna<4,>=2.5 in a:\new folder\lib\site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in a:\new folder\lib\site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in a:\new folder\lib\site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (1.26.11)
# Requirement already satisfied: notebook>=4.4.1 in a:\new folder\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (6.4.12)
# Requirement already satisfied: soupsieve>1.2 in a:\new folder\lib\site-packages (from beautifulsoup4->gdown->leafmap) (2.3.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in a:\new folder\lib\site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in a:\new folder\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in a:\new folder\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0.0->leafmap) (0.18.0)
# Requirement already satisfied: entrypoints in a:\new folder\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (0.4)
# Requirement already satisfied: pywin32>=1.0 in a:\new folder\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets<8.0.0->leafmap) (302)
# Requirement already satisfied: Send2Trash>=1.8.0 in a:\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in a:\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (0.13.1)
# Requirement already satisfied: prometheus-client in a:\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in a:\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (6.4.4)
# Requirement already satisfied: argon2-cffi in a:\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (21.3.0)
# Requirement already satisfied: wcwidth in a:\new folder\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.2.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in a:\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (1.5.0)
# Requirement already satisfied: bleach in a:\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in a:\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (0.8.4)
# Requirement already satisfied: defusedxml in a:\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in a:\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in a:\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (0.1.2)
# Requirement already satisfied: testpath in a:\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (0.6.0)
# Requirement already satisfied: pywinpty>=1.1.0 in a:\new folder\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in a:\new folder\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in a:\new folder\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (1.15.1)
# Requirement already satisfied: webencodings in a:\new folder\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (0.5.1)
# Requirement already satisfied: pycparser in a:\new folder\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0->leafmap) (2.21)
# Installing collected packages: pystac, pystac-client, folium, leafmap
#   Attempting uninstall: folium
#     Found existing installation: folium 0.14.0
#     Uninstalling folium-0.14.0:
#       Successfully uninstalled folium-0.14.0
# Successfully installed folium-0.13.0 leafmap-0.18.5 pystac-1.7.0 pystac-client-0.6.1

# %%
import leafmap
import geopandas as gpd

# %%
leafmap.maxar_collections()
# Out:
# ['Gambia-flooding-8-11-2022',
#  'Hurricane-Fiona-9-19-2022',
#  'Hurricane-Ian-9-26-2022',
#  'Indonesia-Earthquake22',
#  'Kahramanmaras-turkey-earthquake-23',
#  'New-Zealand-Flooding22',
#  'New-Zealand-Flooding23',
#  'Sudan-flooding-8-22-2022',
#  'afghanistan-earthquake22',
#  'cyclone-emnati22',
#  'kentucky-flooding-7-29-2022',
#  'pakistan-flooding22',
#  'southafrica-flooding22',
#  'tonga-volcano21',
#  'volcano-indonesia21',
#  'yellowstone-flooding22']

# %%
collection = 'Kahramanmaras-turkey-earthquake-23'
url = leafmap.maxar_collection_url(collection, dtype='geojson')
url
# Out:
# 'https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/Kahramanmaras-turkey-earthquake-23.geojson'

# %%
gdf = gpd.read_file(url)
print(f'Total number of images: {len(gdf)}')
gdf.head()
# Out:
# Total number of images: 1260
#                    datetime platform   gsd ard_metadata_version  \
# 0 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 1 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 2 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 3 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 4 2021-02-28 08:10:23+00:00     WV03  0.39                0.0.1
#
#          catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 0  1040010067C49900        37  120020230322            29.4          22.0
# 1  1040010067C49900        37  120020230323            29.3          21.3
# 2  1040010067C49900        37  120020230332            29.1          20.6
# 3  1040010067C49900        37  120020230333            29.1          20.3
# 4  1040010067C49900        37  120020232100            29.4          21.8
#
#    view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 0                  57.4             153.1                40.6      32637
# 1                  57.6             153.1                40.6      32637
# 2                  57.8             153.1                40.6      32637
# 3                  57.8             153.1                40.6      32637
# 4                  57.4             153.1                40.6      32637
#
#                grid:code                                          proj:bbox  \
# 0  MXRA-Z37-120020230322  600452.7792440292,4199843.75,605156.25,4204327...
# 1  MXRA-Z37-120020230323   604843.75,4199843.75,610156.25,4204393.030737486
# 2  MXRA-Z37-120020230332  609843.75,4199843.75,615155.9736693815,4204458...
# 3  MXRA-Z37-120020230333  614843.75,4199843.75,615155.9736693815,4204458...
# 4  MXRA-Z37-120020232100   600503.194703785,4194843.75,605156.25,4200156.25
#
#    tile:data_area  tile:clouds_area  tile:clouds_percent  \
# 0            20.8               0.0                    0
# 1            23.9               0.0                    0
# 2            24.1               0.0                    0
# 3             1.2               0.0                    0
# 4            24.5               0.0                    0
#
#                                               visual  \
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                             geometry
# 0  POLYGON ((40.19672 37.94010, 40.14382 37.94062...
# 1  POLYGON ((40.25361 37.93950, 40.19317 37.94013...
# 2  POLYGON ((40.25006 37.93954, 40.25075 37.98047...
# 3  POLYGON ((40.30694 37.93892, 40.30768 37.98047...
# 4  POLYGON ((40.19677 37.94291, 40.19599 37.89504...

# %%
m = leafmap.Map()
m.add_gdf(gdf, layer_name='Footprints')
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
pre_gdf = leafmap.maxar_search(collection, end_date='2023-02-06')
print(f'Total number of pre-event images: {len(pre_gdf)}')
pre_gdf.head()
# Out:
# Total number of pre-event images: 229
#                    datetime platform   gsd ard_metadata_version  \
# 0 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 1 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 2 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 3 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 4 2021-02-28 08:10:23+00:00     WV03  0.39                0.0.1
#
#          catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 0  1040010067C49900        37  120020230322            29.4          22.0
# 1  1040010067C49900        37  120020230323            29.3          21.3
# 2  1040010067C49900        37  120020230332            29.1          20.6
# 3  1040010067C49900        37  120020230333            29.1          20.3
# 4  1040010067C49900        37  120020232100            29.4          21.8
#
#    view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 0                  57.4             153.1                40.6      32637
# 1                  57.6             153.1                40.6      32637
# 2                  57.8             153.1                40.6      32637
# 3                  57.8             153.1                40.6      32637
# 4                  57.4             153.1                40.6      32637
#
#                grid:code                                          proj:bbox  \
# 0  MXRA-Z37-120020230322  600452.7792440292,4199843.75,605156.25,4204327...
# 1  MXRA-Z37-120020230323   604843.75,4199843.75,610156.25,4204393.030737486
# 2  MXRA-Z37-120020230332  609843.75,4199843.75,615155.9736693815,4204458...
# 3  MXRA-Z37-120020230333  614843.75,4199843.75,615155.9736693815,4204458...
# 4  MXRA-Z37-120020232100   600503.194703785,4194843.75,605156.25,4200156.25
#
#    tile:data_area  tile:clouds_area  tile:clouds_percent  \
# 0            20.8               0.0                    0
# 1            23.9               0.0                    0
# 2            24.1               0.0                    0
# 3             1.2               0.0                    0
# 4            24.5               0.0                    0
#
#                                               visual  \
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                             geometry
# 0  POLYGON ((40.19672 37.94010, 40.14382 37.94062...
# 1  POLYGON ((40.25361 37.93950, 40.19317 37.94013...
# 2  POLYGON ((40.25006 37.93954, 40.25075 37.98047...
# 3  POLYGON ((40.30694 37.93892, 40.30768 37.98047...
# 4  POLYGON ((40.19677 37.94291, 40.19599 37.89504...

# %%
post_gdf = leafmap.maxar_search(collection, start_date='2023-02-06')
print(f'Total number of post-event images: {len(post_gdf)}')
post_gdf.head()
# Out:
# Total number of post-event images: 1031
#                      datetime platform   gsd ard_metadata_version  \
# 229 2023-02-07 08:27:01+00:00     WV03  0.31                0.0.1
# 230 2023-02-07 08:27:01+00:00     WV03  0.31                0.0.1
# 231 2023-02-07 08:27:01+00:00     WV03  0.31                0.0.1
# 232 2023-02-07 08:27:01+00:00     WV03  0.31                0.0.1
# 233 2023-02-07 08:27:02+00:00     WV03  0.31                0.0.1
#
#            catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 229  1040010082698700        37  031133010300             5.7         180.5
# 230  1040010082698700        37  031133010301             5.7         181.3
# 231  1040010082698700        37  031133010310             5.7         186.0
# 232  1040010082698700        37  031133010311             5.8         188.8
# 233  1040010082698700        37  031133010302             5.7         180.6
#
#      view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 229                  83.8             156.3                34.2      32637
# 230                  83.8             156.3                34.2      32637
# 231                  83.7             156.3                34.2      32637
# 232                  83.7             156.3                34.2      32637
# 233                  83.7             156.3                34.2      32637
#
#                  grid:code                                          proj:bbox  \
# 229  MXRA-Z37-031133010300  284307.55615234375,4134843.75,285156.25,413773...
# 230  MXRA-Z37-031133010301  284843.75,4134843.75,290156.25,4137711.7919921875
# 231  MXRA-Z37-031133010310  289843.75,4134843.75,295156.25,4137567.7490234375
# 232  MXRA-Z37-031133010311  294843.75,4134843.75,297504.8828125,4137500.61...
# 233  MXRA-Z37-031133010302   284180.908203125,4129843.75,285156.25,4135156.25
#
#      tile:data_area  tile:clouds_area  tile:clouds_percent  \
# 229             2.3               0.0                    0
# 230            14.8               0.1                    0
# 231            14.2               0.0                    0
# 232             6.9               0.0                    0
# 233             4.8               0.0                    0
#
#                                                 visual  \
# 229  https://maxar-opendata.s3.amazonaws.com/events...
# 230  https://maxar-opendata.s3.amazonaws.com/events...
# 231  https://maxar-opendata.s3.amazonaws.com/events...
# 232  https://maxar-opendata.s3.amazonaws.com/events...
# 233  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                               geometry
# 229  POLYGON ((36.56529 37.36127, 36.57405 37.36116...
# 230  POLYGON ((36.57052 37.36120, 36.57135 37.33537...
# 231  POLYGON ((36.62697 37.36105, 36.62774 37.33652...
# 232  POLYGON ((36.68693 37.36163, 36.69621 37.36150...
# 233  POLYGON ((36.56530 37.33806, 36.57478 37.33826...

# %%
m = leafmap.Map()
pre_style = {'color': 'red', 'fillColor': 'red', 'opacity': 1, 'fillOpacity': 0.5}
m.add_gdf(pre_gdf, layer_name='Pre-event', style=pre_style, info_mode='on_click')
m.add_gdf(post_gdf, layer_name='Post-event', info_mode='on_click')
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
bbox = m.user_roi_bounds()
if bbox is None:
    bbox = [36.8715, 37.5497, 36.9814, 37.6019]

# %%
pre_event = leafmap.maxar_search(collection, bbox=bbox, end_date='2023-02-06')
pre_event.head()
# Out:
#                      datetime platform   gsd ard_metadata_version  \
# 98  2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
# 99  2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
# 100 2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
# 101 2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
#
#            catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 98   10300100D797E100        37  031131233232            23.2         143.9
# 99   10300100D797E100        37  031131233233            23.1         144.6
# 100  10300100D797E100        37  031133011010            23.1         143.8
# 101  10300100D797E100        37  031133011011            22.9         144.5
#
#      view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 98                   63.7             130.7                65.1      32637
# 99                   63.9             130.7                65.1      32637
# 100                  63.9             130.7                65.1      32637
# 101                  64.1             130.7                65.1      32637
#
#                  grid:code                                          proj:bbox  \
# 98   MXRA-Z37-031131233232  314738.45123535924,4159843.75,315156.25,416316...
# 99   MXRA-Z37-031131233233  314843.75,4159843.75,319758.3041869086,4163163...
# 100  MXRA-Z37-031133011010  314714.4264589311,4158758.460866644,315156.25,...
# 101  MXRA-Z37-031133011011  314843.75,4158659.1890106304,319695.2811615013...
#
#      tile:data_area  tile:clouds_area  tile:clouds_percent  \
# 98              1.2               0.0                    0
# 99             15.9               0.0                    0
# 100             0.5               0.0                    0
# 101             6.9               0.0                    0
#
#                                                 visual  \
# 98   https://maxar-opendata.s3.amazonaws.com/events...
# 99   https://maxar-opendata.s3.amazonaws.com/events...
# 100  https://maxar-opendata.s3.amazonaws.com/events...
# 101  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                               geometry
# 98   POLYGON ((36.90702 37.56709, 36.90229 37.56701...
# 99   POLYGON ((36.90348 37.56703, 36.90264 37.59693...
# 100  POLYGON ((36.90694 37.56991, 36.90729 37.55732...
# 101  POLYGON ((36.90340 37.56984, 36.95831 37.57081...

# %%
post_event = leafmap.maxar_search(collection, bbox=bbox, start_date='2023-02-06')
post_event.head()
# Out:
#                      datetime platform   gsd ard_metadata_version  \
# 435 2023-02-08 09:02:04+00:00     WV02  0.78                0.0.1
# 436 2023-02-08 09:02:04+00:00     WV02  0.79                0.0.1
# 439 2023-02-08 09:02:04+00:00     WV02  0.79                0.0.1
# 446 2023-02-08 09:02:04+00:00     WV02  0.78                0.0.1
# 447 2023-02-08 09:02:04+00:00     WV02  0.79                0.0.1
#
#            catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 435  10300500D9F8D200        37  031131233232            40.2         273.1
# 436  10300500D9F8D200        37  031131233233            40.4         273.1
# 439  10300500D9F8D200        37  031131233322            40.6         273.1
# 446  10300500D9F8D200        37  031133011010            40.3         273.3
# 447  10300500D9F8D200        37  031133011011            40.5         273.3
#
#      view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 435                  43.6             166.6                36.6      32637
# 436                  43.4             166.6                36.6      32637
# 439                  43.1             166.6                36.6      32637
# 446                  43.6             166.6                36.7      32637
# 447                  43.3             166.6                36.7      32637
#
#                  grid:code                                  proj:bbox  \
# 435  MXRA-Z37-031131233232  309843.75,4159843.75,315156.25,4165156.25
# 436  MXRA-Z37-031131233233  314843.75,4159843.75,320156.25,4165156.25
# 439  MXRA-Z37-031131233322  319843.75,4159843.75,325156.25,4165156.25
# 446  MXRA-Z37-031133011010  309843.75,4154843.75,315156.25,4160156.25
# 447  MXRA-Z37-031133011011  314843.75,4154843.75,320156.25,4160156.25
#
#      tile:data_area  tile:clouds_area  tile:clouds_percent  \
# 435            28.2               0.0                    0
# 436            28.2               0.0                    0
# 439            28.2               0.0                    0
# 446            28.2               0.5                    1
# 447            28.2               0.1                    0
#
#                                                 visual  \
# 435  https://maxar-opendata.s3.amazonaws.com/events...
# 436  https://maxar-opendata.s3.amazonaws.com/events...
# 439  https://maxar-opendata.s3.amazonaws.com/events...
# 446  https://maxar-opendata.s3.amazonaws.com/events...
# 447  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                               geometry
# 435  POLYGON ((36.84552 37.61386, 36.84690 37.56601...
# 436  POLYGON ((36.90214 37.61488, 36.90348 37.56703...
# 439  POLYGON ((36.95876 37.61588, 36.96006 37.56802...
# 446  POLYGON ((36.84682 37.56883, 36.84820 37.52098...
# 447  POLYGON ((36.90340 37.56984, 36.90474 37.52199...

# %%
pre_tile = pre_event['catalog_id'].values[0]
pre_tile
# Out:
# '10300100D797E100'

# %%
post_tile = post_event['catalog_id'].values[0]
post_tile
# Out:
# '10300500D9F8D200'

# %%
pre_stac = leafmap.maxar_tile_url(collection, pre_tile, dtype='json')
pre_stac
# Out:
# 'https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/Kahramanmaras-turkey-earthquake-23/10300100D797E100.json'

# %%
post_stac = leafmap.maxar_tile_url(collection, post_tile, dtype='json')
post_stac
# Out:
# 'https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/Kahramanmaras-turkey-earthquake-23/10300500D9F8D200.json'

# %%
import leafmap.foliumap as leafmap

# %%
m = leafmap.Map()
m.split_map(
    left_layer=pre_stac,
    right_layer=post_stac,
    left_label='Pre-event',
    right_label='Post-event',
)
m.set_center(36.9265, 37.5762, 16)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec4d6f271b5995a7b22bad628420b8ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec4d6f271b5995a7b22bad628420b8ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec4d6f271b5995a7b22bad628420b8ee = L.map(
#                 &quot;map_ec4d6f271b5995a7b22bad628420b8ee&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_ec4d6f271b5995a7b22bad628420b8ee);
#
#
#
#
#
#             var tile_layer_ba97dc5ca5d463f31da8dd23b3560528 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec4d6f271b5995a7b22bad628420b8ee);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_ec4d6f271b5995a7b22bad628420b8ee);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_ec4d6f271b5995a7b22bad628420b8ee
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_d0b6fa6bbfef61f073da2f0c6f323003 = new L.Control.Draw(
#                 options
#             ).addTo( map_ec4d6f271b5995a7b22bad628420b8ee );
#             map_ec4d6f271b5995a7b22bad628420b8ee.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_ec4d6f271b5995a7b22bad628420b8ee.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_fe30d4f586202b739e722da26c36b5af = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_ec4d6f271b5995a7b22bad628420b8ee.addControl(measure_control_fe30d4f586202b739e722da26c36b5af);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_ec4d6f271b5995a7b22bad628420b8ee.setView(e.geocode.center, 11);
#             }).addTo(map_ec4d6f271b5995a7b22bad628420b8ee);
#
#
#
#             map_ec4d6f271b5995a7b22bad628420b8ee.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_cde1d41cde2b1c8af3f98fe3500102b2 = L.tileLayer(
#                 &quot;https://titiler.xyz/mosaicjson/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?max_zoom=100\u0026max_native_zoom=100\u0026layer_name=Left+Layer\u0026url=https%3A%2F%2Fraw.githubusercontent.com%2Fgiswqs%2Fmaxar-open-data%2Fmaster%2Fdatasets%2FKahramanmaras-turkey-earthquake-23%2F10300100D797E100.json&quot;,
#                 {&quot;attribution&quot;: &quot; &quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot

# %%
pre_images = pre_event['visual'].tolist()
post_images = post_event['visual'].tolist()

# %%
leafmap.maxar_download(pre_images)
# Out:
# C:\Users\angad\10300100D797E100\031131233232.tif already exists. Skipping...
# C:\Users\angad\10300100D797E100\031131233233.tif already exists. Skipping...
# C:\Users\angad\10300100D797E100\031133011010.tif already exists. Skipping...
# C:\Users\angad\10300100D797E100\031133011011.tif already exists. Skipping...

# %%
leafmap.maxar_download(pre_images)
# Out:
# C:\Users\angad\10300100D797E100\031131233232.tif already exists. Skipping...
# C:\Users\angad\10300100D797E100\031131233233.tif already exists. Skipping...
# C:\Users\angad\10300100D797E100\031133011010.tif already exists. Skipping...
# C:\Users\angad\10300100D797E100\031133011011.tif already exists. Skipping...
